# %%
from IPython.display import display, Image, clear_output

# %% [markdown]
# # Comprehensive Lipidome Automation Workflow (CLAW)
#
# Welcome to CLAW, a tool designed to facilitate and optimize the processing of lipidomic MRM data. This Jupyter notebook encapsulates a suite of tools that streamline the various stages of lipidomics data analysis.
#
# Our toolset enables users to efficiently process MRM data files in the mzML format. Upload a file and CLAW will parse the data into a structured Pandas dataframe. This dataframe includes critical information like sample_ID, MRM transition, and signal intensity. Furthermore, our tool aligns each MRM transition with a default or custom lipid_database for accurate and swift annotation.
#
# Moreover, CLAW is equipped with an OzESI option, a tool to elucidate the double bond location in lipid isomers. This feature allows users to input OzESI data and pinpoint the precise location of double bonds in isomeric lipids. Users have the flexibility to select which double bond locations they want to analyze. Following this, CLAW autonomously predicts potential m/z values and cross-references these predictions with sample data, ensuring a comprehensive and meticulous analysis.
#
# With automation at its core, CLAW eliminates the need for manual data processing, significantly reducing time expenditure. It is a robust and invaluable tool for handling large volumes of lipid MRM data, accelerating scientific discovery in the field of lipidomics.

# %%
# ============================================================================
# IMPORTS
# ============================================================================

# Standard library imports
import os
import csv
import json
import importlib
from pathlib import Path

# Third-party imports
import pymzml
import pandas as pd
import numpy as np
import plotly.graph_objs as go

# CLAW library imports
# import CLAW_OzESI
# import plot_TG
# import plot

# # Reload modules for development
# importlib.reload(CLAW_OzESI)
# importlib.reload(plot_TG)
# importlib.reload(plot)

# Import specific functions/classes
from scripts.CLAW_OzESI import Parse, ion_label_parser
from scripts.plot import plot_n9_n7_ratios, plot_n9_n7_ratios_intensity, calculate_ratio_statistics
from pathlib import Path

# %% [markdown]
# ## Pre-Parsing Setup
#
# This section parses mzML files and extracts MRM transition data into a structured format for analysis. The `CLAW_OzESI.parsing_mzml_to_df` function reads raw mass spectrometry data, matches it against a lipid database, and organizes the results into a pandas DataFrame.
#
# The function requires several inputs to configure the parsing process:
#
# **Database and file locations:**
# - `data_base_name_location`: Path to the lipid database containing lipid MRM transitions
# - `Project_Folder_data`: Directory containing the mzML files to be analyzed
#
# **Matching parameters:**
# - `tolerance`: Acceptable deviation range (in m/z units) when matching detected transitions to the database
# - `remove_std`: When set to `True`, filters out transitions corresponding to internal or external standards
#
# The function returns a pandas DataFrame where each row represents a detected MRM transition. Key columns include the sample ID, MRM transition (parent → product ion), and signal intensity, along with additional metadata for downstream analysis.

# %%
# PATHS:
data_base_name_location = "/scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/lipid_database/Lipid_Database.xlsx"
Project_Folder_data = "/scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/mzml/ON"
analysis_dir = "/scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results"
Project_results = "/scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results"
file_name_to_save = "parsed_results"
tolerance = 0.3

# %% [markdown]
# # Run CLAW parsing

# %%
# Create parser with corrected path
parser = Parse(
    data_base_name_location=data_base_name_location,
    Project_Folder_data=Project_Folder_data,
    Project_results=Project_results,
    file_name_to_save=file_name_to_save,
    tolerance=tolerance,
    remove_std=True,
    save_data=False,
    batch_processing=True,
    plot_chromatogram=True
)

# Run the parser
df_MRM, df_OzESI, df_OzESI_matched = parser.mrm_run_all(deuterated=False)

# Check the results
print(f"df_MRM shape: {df_MRM.shape}")
print(f"df_OzESI shape: {df_OzESI.shape}")
print(f"df_OzESI_matched shape: {df_OzESI_matched.shape}")
# Out:
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lipid_MRM_data['Parent_Ion'] = np.round(lipid_MRM_data['Parent_Ion'], 1)
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lipid_MRM_data['Product_Ion'] = np.round(lipid_MRM_data['Product_Ion'], 1)
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lipid_MRM_data['Transition'] = lipid_MRM_data['Parent_Ion'].astype(str) + ' -> ' + lipid_MRM_data['Product_Ion'].astype(str)
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:74: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   OzESI_time_df = pd.concat([OzESI_time_df, pd.DataFrame(ozesi_rows)], ignore_index=True)
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:75: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   master_df = pd.concat([master_df, df], ignore_index=True)
# Finished parsing mzML file: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/mzml/ON/CrudeCanola_O3on_150gN3_02082023.mzML
#
# Finished parsing mzML file: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/mzml/ON/DegummedCanola_O3on_150gN3_02082023.mzML
#
# Finished parsing mzML file: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/mzml/ON/RBDCanola_O3on_150gN3_02082023.mzML
#
# Finished parsing all mzML files
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lipid_MRM_data['Parent_Ion'] = np.round(lipid_MRM_data['Parent_Ion'], 1)
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lipid_MRM_data['Product_Ion'] = np.round(lipid_MRM_data['Product_Ion'], 1)
# /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/scripts/CLAW_OzESI.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lipid_MRM_data['Transition'] = lipid_MRM_data['Parent_Ion'].astype(str) + ' -> ' + lipid_MRM_data['Product_Ion'].astype(str)
# df_MRM shape: (105, 7)
# df_OzESI shape: (225357, 7)
# df_OzESI_matched shape: (225357, 8)

# %% [markdown]
# Define the master dataframes where the data will be stored during the parsing step.

# %% [markdown]
# ## CLAW.full_parse()
# In this code, the `CLAW.full_parse()` function is used to analyze the MRM data. It takes several parameters like the location of the lipid database, paths to the data and results folders, the name of the result files, and the tolerance for MRM transitions matching. The function returns two dataframes: `df_matched` that contains information about each detected lipid species and their corresponding MRM transitions, and `OzESI_time_df` which captures data related to OzESI-MS scans, including potential double bond locations of lipids. If `remove_std` is `True`, it removes MRM transitions related to standards from the dataframe, and if `save_data` is `True`, the dataframe is saved as a .csv file in the specified results folder.

# %%
df_MRM.head(None)
# Out:
#     Class     Intensity                        Lipid  Parent_Ion  Product_Ion  \
# 0     NaN  5.451378e+05                          NaN       760.6      571.596
# 1     NaN  6.208219e+05                          NaN       762.6      573.596
# 2     NaN  9.441859e+05                          NaN       764.6      575.596
# 3     NaN  1.137434e+06                          NaN       766.7      577.596
# 4     NaN  5.900676e+05                          NaN       782.6      593.596
# ..    ...           ...                          ...         ...          ...
# 100   TAG  4.897507e+05            [TG(54:6)]_FA18:1       896.8      597.596
# 101   TAG  1.179904e+06            [TG(54:5)]_FA18:1       898.8      599.596
# 102   TAG  1.654774e+06  [TG(55:11),TG(54:4)]_FA18:1       900.8      601.596
# 103   TAG  5.234119e+06  [TG(55:10),TG(54:3)]_FA18:1       902.8      603.596
# 104   TAG  2.793856e+06   [TG(55:9),TG(54:2)]_FA18:1       904.8      605.596
#
#                             Sample_ID        Transition
# 0    CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 1    CrudeCanola_O3on_150gN3_02082023  762.6 -> 573.596
# 2    CrudeCanola_O3on_150gN3_02082023  764.6 -> 575.596
# 3    CrudeCanola_O3on_150gN3_02082023  766.7 -> 577.596
# 4    CrudeCanola_O3on_150gN3_02082023  782.6 -> 593.596
# ..                                ...               ...
# 100    RBDCanola_O3on_150gN3_02082023  896.8 -> 597.596
# 101    RBDCanola_O3on_150gN3_02082023  898.8 -> 599.596
# 102    RBDCanola_O3on_150gN3_02082023  900.8 -> 601.596
# 103    RBDCanola_O3on_150gN3_02082023  902.8 -> 603.596
# 104    RBDCanola_O3on_150gN3_02082023  904.8 -> 605.596
#
# [105 rows x 7 columns]

# %% [markdown]
# The `read_mrm_list()` function is first invoked to read the MRM database from the specified file location and return it as a pandas DataFrame `mrm_database`. Subsequently, the `match_lipids_parser()` function is called to match the detected lipids from the `OzESI_time_df` DataFrame, obtained from the OzESI-MS scans, with the known lipids in the `mrm_database` based on the MRM transitions within the specified `tolerance`. The result is saved in the `df_oz_matched` DataFrame, which now contains matched lipid species from the OzESI-MS data.

# %% [markdown]
# ### Confirm OzESI df before parsing data

# %%
df_OzESI
# Out:
#        Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0        NaN       760.6      571.596        0.015933       190.400009
# 1        NaN       760.6      571.596        0.032233       147.420013
# 2        NaN       760.6      571.596        0.048550       153.620010
# 3        NaN       760.6      571.596        0.064850       200.080017
# 4        NaN       760.6      571.596        0.081167       206.900009
# ...      ...         ...          ...             ...              ...
# 225352   NaN       904.8      605.596       34.931700       148.500015
# 225353   NaN       904.8      605.596       34.948000       131.800003
# 225354   NaN       904.8      605.596       34.964317       151.960007
# 225355   NaN       904.8      605.596       34.980617       137.700012
# 225356   NaN       904.8      605.596       34.996933       103.460007
#
#                                Sample_ID        Transition
# 0       CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 1       CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 2       CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 3       CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 4       CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# ...                                  ...               ...
# 225352    RBDCanola_O3on_150gN3_02082023  904.8 -> 605.596
# 225353    RBDCanola_O3on_150gN3_02082023  904.8 -> 605.596
# 225354    RBDCanola_O3on_150gN3_02082023  904.8 -> 605.596
# 225355    RBDCanola_O3on_150gN3_02082023  904.8 -> 605.596
# 225356    RBDCanola_O3on_150gN3_02082023  904.8 -> 605.596
#
# [225357 rows x 7 columns]

# %%
df_OzESI_matched.to_csv('df_OzESI_matched.csv')
df_OzESI_matched
# Out:
#        Class                       Lipid  OzESI_Intensity  Parent_Ion  \
# 0        NaN                         NaN       190.400009       760.6
# 1        NaN                         NaN       147.420013       760.6
# 2        NaN                         NaN       153.620010       760.6
# 3        NaN                         NaN       200.080017       760.6
# 4        NaN                         NaN       206.900009       760.6
# ...      ...                         ...              ...         ...
# 225352   TAG  [TG(55:9),TG(54:2)]_FA18:1       148.500015       904.8
# 225353   TAG  [TG(55:9),TG(54:2)]_FA18:1       131.800003       904.8
# 225354   TAG  [TG(55:9),TG(54:2)]_FA18:1       151.960007       904.8
# 225355   TAG  [TG(55:9),TG(54:2)]_FA18:1       137.700012       904.8
# 225356   TAG  [TG(55:9),TG(54:2)]_FA18:1       103.460007       904.8
#
#         Product_Ion  Retention_Time                         Sample_ID  \
# 0           571.596        0.015933  CrudeCanola_O3on_150gN3_02082023
# 1           571.596        0.032233  CrudeCanola_O3on_150gN3_02082023
# 2           571.596        0.048550  CrudeCanola_O3on_150gN3_02082023
# 3           571.596        0.064850  CrudeCanola_O3on_150gN3_02082023
# 4           571.596        0.081167  CrudeCanola_O3on_150gN3_02082023
# ...             ...             ...                               ...
# 225352      605.596       34.931700    RBDCanola_O3on_150gN3_02082023
# 225353      605.596       34.948000    RBDCanola_O3on_150gN3_02082023
# 225354      605.596       34.964317    RBDCanola_O3on_150gN3_02082023
# 225355      605.596       34.980617    RBDCanola_O3on_150gN3_02082023
# 225356      605.596       34.996933    RBDCanola_O3on_150gN3_02082023
#
#               Transition
# 0       760.6 -> 571.596
# 1       760.6 -> 571.596
# 2       760.6 -> 571.596
# 3       760.6 -> 571.596
# 4       760.6 -> 571.596
# ...                  ...
# 225352  904.8 -> 605.596
# 225353  904.8 -> 605.596
# 225354  904.8 -> 605.596
# 225355  904.8 -> 605.596
# 225356  904.8 -> 605.596
#
# [225357 rows x 8 columns]

# %% [markdown]
# # Match user selected ion labels with OzESI_Matched Data using m/z and retention time tolerances (±0.3 Da, ±1.0 min)

# %%
# Call the function

lipid_mrm = pd.read_csv("Projects/canola_tutorial/results/lipid_mrm.csv")
df_canola_lipids = ion_label_parser(
    lipid_mrm=lipid_mrm,
    df_OzESI_matched=df_OzESI_matched,
    ion_tolerance=0.3,
    rt_tolerance=1.0,
    ion_labels=['n-7', 'n-9']  # Select double bond locations
)

# %%
# DIAGNOSTIC: Check why ion_label_parser returns empty
print("=" * 60)
print("DEBUGGING ion_label_parser")
print("=" * 60)

# Check lipid_mrm
print("\n1. lipid_mrm DataFrame:")
print(f"   Shape: {lipid_mrm.shape}")
print(f"   Columns: {lipid_mrm.columns.tolist()}")
print("\n   First few rows:")
print(lipid_mrm.head())

# Check df_OzESI_matched
print("\n2. df_OzESI_matched DataFrame:")
print(f"   Shape: {df_OzESI_matched.shape}")
print(f"   Columns: {df_OzESI_matched.columns.tolist()}")
if len(df_OzESI_matched) > 0:
    print(f"   Sample_IDs: {df_OzESI_matched['Sample_ID'].unique()}")
    print(f"   Parent_Ion range: {df_OzESI_matched['Parent_Ion'].min():.1f} - {df_OzESI_matched['Parent_Ion'].max():.1f}")
    print(f"   Product_Ion range: {df_OzESI_matched['Product_Ion'].min():.1f} - {df_OzESI_matched['Product_Ion'].max():.1f}")
    print(f"   RT range: {df_OzESI_matched['Retention_Time'].min():.2f} - {df_OzESI_matched['Retention_Time'].max():.2f}")
    print("\n   First few rows:")
    print(df_OzESI_matched.head())
else:
    print("   ⚠️ df_OzESI_matched is EMPTY!")

# Manual test of one match
if len(lipid_mrm) > 0 and len(df_OzESI_matched) > 0:
    print("\n3. Testing first lipid match:")
    test_row = lipid_mrm.iloc[0]
    print(f"   Looking for: {test_row['Lipid']}")
    print(f"   Product_Ion: {test_row['Product_Ion']}")
    print(f"   RT: {test_row['Retention_Time']}")
    print(f"   n-7 ion: {test_row['n-7']}")
    print(f"   n-9 ion: {test_row['n-9']}")
    
    # Check if any matches exist
    matches = df_OzESI_matched[
        (df_OzESI_matched['Product_Ion'].between(test_row['Product_Ion'] - 0.3, test_row['Product_Ion'] + 0.3))
    ]
    print(f"\n   Product ion matches: {len(matches)}")
    if len(matches) > 0:
        print(matches[['Parent_Ion', 'Product_Ion', 'Retention_Time', 'Sample_ID']].head())

print("=" * 60)
# Out:
# ============================================================
# DEBUGGING ion_label_parser
# ============================================================
#
# 1. lipid_mrm DataFrame:
#    Shape: (7, 6)
#    Columns: ['Lipid', 'Precursor_Ion', 'Product_Ion', 'n-7', 'n-9', 'Retention_Time']
#
#    First few rows:
#                Lipid  Precursor_Ion  Product_Ion    n-7    n-9  Retention_Time
# 0  [TG(52:2)]_FA18:1          876.8      577.596  794.8  766.8           18.05
# 1  [TG(52:3)]_FA18:1          874.8      575.596  792.8  764.8           16.09
# 2  [TG(52:4)]_FA18:1          872.8      573.596  790.8  762.8           14.30
# 3  [TG(54:2)]_FA18:1          904.8      605.596  822.8  794.8           20.00
# 4  [TG(54:3)]_FA18:1          902.8      603.596  820.8  792.8           17.98
#
# 2. df_OzESI_matched DataFrame:
#    Shape: (225357, 8)
#    Columns: ['Class', 'Lipid', 'OzESI_Intensity', 'Parent_Ion', 'Product_Ion', 'Retention_Time', 'Sample_ID', 'Transition']
#    Sample_IDs: ['CrudeCanola_O3on_150gN3_02082023' 'DegummedCanola_O3on_150gN3_02082023'
#  'RBDCanola_O3on_150gN3_02082023']
#    Parent_Ion range: 760.6 - 904.8
#    Product_Ion range: 569.6 - 605.6
#    RT range: 0.00 - 35.00
#
#    First few rows:
#   Class Lipid  OzESI_Intensity  Parent_Ion  Product_Ion  Retention_Time  \
# 0   NaN   NaN       190.400009       760.6      571.596        0.015933
# 1   NaN   NaN       147.420013       760.6      571.596        0.032233
# 2   NaN   NaN       153.620010       760.6      571.596        0.048550
# 3   NaN   NaN       200.080017       760.6      571.596        0.064850
# 4   NaN   NaN       206.900009       760.6      571.596        0.081167
#
#                           Sample_ID        Transition
# 0  CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 1  CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 2  CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 3  CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
# 4  CrudeCanola_O3on_150gN3_02082023  760.6 -> 571.596
#
# 3. Testing first lipid match:
#    Looking for: [TG(52:2)]_FA18:1
#    Product_Ion: 577.596
#    RT: 18.05
#    n-7 ion: 794.8
#    n-9 ion: 766.8
#
#    Product ion matches: 19317
#       Parent_Ion  Product_Ion  Retention_Time  \
# 6438       766.7      577.596        0.014550
# 6439       766.7      577.596        0.030850
# 6440       766.7      577.596        0.047150
# 6441       766.7      577.596        0.063467
# 6442       766.7      577.596        0.079767
#
#                              Sample_ID
# 6438  CrudeCanola_O3on_150gN3_02082023
# 6439  CrudeCanola_O3on_150gN3_02082023
# 6440  CrudeCanola_O3on_150gN3_02082023
# 6441  CrudeCanola_O3on_150gN3_02082023
# 6442  CrudeCanola_O3on_150gN3_02082023
# ============================================================

# %%
df_canola_lipids
# Out:
#                   Lipid db_pos  Parent_Ion  Product_Ion  Retention_Time  \
# 0     [TG(52:2)]_FA18:1    n-7       794.7      577.596       17.050733
# 1     [TG(52:2)]_FA18:1    n-7       794.7      577.596       17.067050
# 2     [TG(52:2)]_FA18:1    n-7       794.7      577.596       17.083350
# 3     [TG(52:2)]_FA18:1    n-7       794.7      577.596       17.099667
# 4     [TG(52:2)]_FA18:1    n-7       794.7      577.596       17.115967
# ...                 ...    ...         ...          ...             ...
# 5161  [TG(54:5)]_FA18:1    n-9       788.6      599.596       15.243367
# 5162  [TG(54:5)]_FA18:1    n-9       788.6      599.596       15.259667
# 5163  [TG(54:5)]_FA18:1    n-9       788.6      599.596       15.275983
# 5164  [TG(54:5)]_FA18:1    n-9       788.6      599.596       15.292283
# 5165  [TG(54:5)]_FA18:1    n-9       788.6      599.596       15.308600
#
#       OzESI_Intensity                         Sample_ID        Transition
# 0          552.000061  CrudeCanola_O3on_150gN3_02082023  794.7 -> 577.596
# 1          586.240051  CrudeCanola_O3on_150gN3_02082023  794.7 -> 577.596
# 2          489.380035  CrudeCanola_O3on_150gN3_02082023  794.7 -> 577.596
# 3          442.220032  CrudeCanola_O3on_150gN3_02082023  794.7 -> 577.596
# 4          345.980011  CrudeCanola_O3on_150gN3_02082023  794.7 -> 577.596
# ...               ...                               ...               ...
# 5161       802.380066    RBDCanola_O3on_150gN3_02082023  788.6 -> 599.596
# 5162       786.740051    RBDCanola_O3on_150gN3_02082023  788.6 -> 599.596
# 5163       563.920044    RBDCanola_O3on_150gN3_02082023  788.6 -> 599.596
# 5164       703.860046    RBDCanola_O3on_150gN3_02082023  788.6 -> 599.596
# 5165       752.200073    RBDCanola_O3on_150gN3_02082023  788.6 -> 599.596
#
# [5166 rows x 8 columns]

# %% [markdown]
# # Analyze lipid peaks for selected sample and save n-9/n-7 ratio summary table

# %%
SHOW_PLOTS = False  # Set True to display plots

# =====================================================================
# RUN PEAK ANALYSIS
# =====================================================================

summary_df = CLAW_OzESI.peak_analysis(
    df_canola_lipids,
    output_dir=str(analysis_dir),
    show_plots=SHOW_PLOTS,
    plot_TG_module=plot_TG
)
# Out:
# Found 3 samples:
#  • CrudeCanola_O3on_150gN3_02082023
#  • DegummedCanola_O3on_150gN3_02082023
#  • RBDCanola_O3on_150gN3_02082023
#
# 🔍 Processing sample: CrudeCanola_O3on_150gN3_02082023
#
# Peak Analysis for \[TG\(52:2\)\]_FA18:1 in CrudeCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 385.16
#   Retention Time: 18.05
#   Peak Height: 3814.96
#   All 1 peaks:
#     Peak 1 - RT: 18.05, Height: 3814.96, Area: 385.16
# n-9 Largest Peak Area: 1594.45
#   Retention Time: 18.05
#   Peak Height: 16153.12
#   All 1 peaks:
#     Peak 1 - RT: 18.05, Height: 16153.12, Area: 1594.45
#
# n-9/n-7 Ratio (largest peaks only): 4.1397
#
# Peak Analysis for \[TG\(52:3\)\]_FA18:1 in CrudeCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 181.90
#   Retention Time: 16.04
#   Peak Height: 1083.40
#   All 1 peaks:
#     Peak 1 - RT: 16.04, Height: 1083.40, Area: 181.90
# n-9 Largest Peak Area: 403.31
#   Retention Time: 16.09
#   Peak Height: 3419.82
#   All 1 peaks:
#     Peak 1 - RT: 16.09, Height: 3419.82, Area: 403.31
#
# n-9/n-7 Ratio (largest peaks only): 2.2172
#
# Peak Analysis for \[TG\(52:4\)\]_FA18:1 in CrudeCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 113.47
#   Retention Time: 14.31
#   Peak Height: 615.42
#   All 1 peaks:
#     Peak 1 - RT: 14.31, Height: 615.42, Area: 113.47
# n-9 Largest Peak Area: 255.86
#   Retention Time: 14.30
#   Peak Height: 1874.78
#   All 1 peaks:
#     Peak 1 - RT: 14.30, Height: 1874.78, Area: 255.86
#
# n-9/n-7 Ratio (largest peaks only): 2.2548
#
# Peak Analysis for \[TG\(54:2\)\]_FA18:1 in CrudeCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 217.32
#   Retention Time: 19.98
#   Peak Height: 2716.40
#   All 1 peaks:
#     Peak 1 - RT: 19.98, Height: 2716.40, Area: 217.32
# n-9 Largest Peak Area: 1178.19
#   Retention Time: 20.00
#   Peak Height: 11693.08
#   All 1 peaks:
#     Peak 1 - RT: 20.00, Height: 11693.08, Area: 1178.19
#
# n-9/n-7 Ratio (largest peaks only): 5.4214
#
# Peak Analysis for \[TG\(54:3\)\]_FA18:1 in CrudeCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 1585.37
#   Retention Time: 17.98
#   Peak Height: 17186.22
#   All 1 peaks:
#     Peak 1 - RT: 17.98, Height: 17186.22, Area: 1585.37
# n-9 Largest Peak Area: 9933.03
#   Retention Time: 17.98
#   Peak Height: 99860.15
#   All 1 peaks:
#     Peak 1 - RT: 17.98, Height: 99860.15, Area: 9933.03
#
# n-9/n-7 Ratio (largest peaks only): 6.2654
#
# Peak Analysis for \[TG\(54:4\)\]_FA18:1 in CrudeCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 638.03
#   Retention Time: 16.09
#   Peak Height: 5501.26
#   All 1 peaks:
#     Peak 1 - RT: 16.09, Height: 5501.26, Area: 638.03
# n-9 Largest Peak Area: 2811.81
#   Retention Time: 16.07
#   Peak Height: 27000.62
#   All 1 peaks:
#     Peak 1 - RT: 16.07, Height: 27000.62, Area: 2811.81
#
# n-9/n-7 Ratio (largest peaks only): 4.4070
#
# Peak Analysis for \[TG\(54:5\)\]_FA18:1 in CrudeCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 118.33
#   Retention Time: 14.31
#   Peak Height: 1287.48
#   All 1 peaks:
#     Peak 1 - RT: 14.31, Height: 1287.48, Area: 118.33
# n-9 Largest Peak Area: 895.03
#   Retention Time: 14.31
#   Peak Height: 5259.14
#   All 1 peaks:
#     Peak 1 - RT: 14.31, Height: 5259.14, Area: 895.03
#
# n-9/n-7 Ratio (largest peaks only): 7.5637
# ✅ Saved summary results for CrudeCanola_O3on_150gN3_02082023 → /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/df_CrudeCanola_O3on_150gN3_02082023_summary.csv
#    Columns: Sample_ID, Lipid, n-7_Area, n-9_Area, n-9/n-7_Ratio, n-7_Intensity, n-9_Intensity, n-9/n-7_Intensity_Ratio
#
# 🔍 Processing sample: DegummedCanola_O3on_150gN3_02082023
#
# Peak Analysis for \[TG\(52:2\)\]_FA18:1 in DegummedCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 305.48
#   Retention Time: 17.93
#   Peak Height: 2316.06
#   All 1 peaks:
#     Peak 1 - RT: 17.93, Height: 2316.06, Area: 305.48
# n-9 Largest Peak Area: 1127.62
#   Retention Time: 17.94
#   Peak Height: 9987.04
#   All 1 peaks:
#     Peak 1 - RT: 17.94, Height: 9987.04, Area: 1127.62
#
# n-9/n-7 Ratio (largest peaks only): 3.6913
#
# Peak Analysis for \[TG\(52:3\)\]_FA18:1 in DegummedCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 95.04
#   Retention Time: 15.98
#   Peak Height: 954.52
#   All 5 peaks:
#     Peak 1 - RT: 15.44, Height: 583.16, Area: 25.48
#     Peak 2 - RT: 15.98, Height: 954.52, Area: 95.04
#     Peak 3 - RT: 16.42, Height: 582.90, Area: 25.99
#     Peak 4 - RT: 16.68, Height: 619.66, Area: 33.80
#     Peak 5 - RT: 16.79, Height: 577.70, Area: 31.36
# n-9 Largest Peak Area: 295.37
#   Retention Time: 16.01
#   Peak Height: 2387.04
#   All 1 peaks:
#     Peak 1 - RT: 16.01, Height: 2387.04, Area: 295.37
#
# n-9/n-7 Ratio (largest peaks only): 3.1079
#
# Peak Analysis for \[TG\(52:4\)\]_FA18:1 in DegummedCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 101.18
#   Retention Time: 14.20
#   Peak Height: 640.02
#   All 3 peaks:
#     Peak 1 - RT: 13.82, Height: 387.44, Area: 27.54
#     Peak 2 - RT: 14.20, Height: 640.02, Area: 101.18
#     Peak 3 - RT: 14.62, Height: 342.86, Area: 52.13
# n-9 Largest Peak Area: 200.19
#   Retention Time: 14.19
#   Peak Height: 1896.60
#   All 1 peaks:
#     Peak 1 - RT: 14.19, Height: 1896.60, Area: 200.19
#
# n-9/n-7 Ratio (largest peaks only): 1.9786
#
# Peak Analysis for \[TG\(54:2\)\]_FA18:1 in DegummedCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 194.40
#   Retention Time: 19.95
#   Peak Height: 1344.72
#   All 1 peaks:
#     Peak 1 - RT: 19.95, Height: 1344.72, Area: 194.40
# n-9 Largest Peak Area: 577.20
#   Retention Time: 19.92
#   Peak Height: 5166.14
#   All 1 peaks:
#     Peak 1 - RT: 19.92, Height: 5166.14, Area: 577.20
#
# n-9/n-7 Ratio (largest peaks only): 2.9691
#
# Peak Analysis for \[TG\(54:3\)\]_FA18:1 in DegummedCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 1060.20
#   Retention Time: 17.90
#   Peak Height: 10785.36
#   All 1 peaks:
#     Peak 1 - RT: 17.90, Height: 10785.36, Area: 1060.20
# n-9 Largest Peak Area: 6127.10
#   Retention Time: 17.88
#   Peak Height: 61997.80
#   All 1 peaks:
#     Peak 1 - RT: 17.88, Height: 61997.80, Area: 6127.10
#
# n-9/n-7 Ratio (largest peaks only): 5.7792
#
# Peak Analysis for \[TG\(54:4\)\]_FA18:1 in DegummedCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 305.61
#   Retention Time: 15.96
#   Peak Height: 3479.06
#   All 1 peaks:
#     Peak 1 - RT: 15.96, Height: 3479.06, Area: 305.61
# n-9 Largest Peak Area: 1512.69
#   Retention Time: 15.98
#   Peak Height: 14145.28
#   All 1 peaks:
#     Peak 1 - RT: 15.98, Height: 14145.28, Area: 1512.69
#
# n-9/n-7 Ratio (largest peaks only): 4.9498
#
# Peak Analysis for \[TG\(54:5\)\]_FA18:1 in DegummedCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 84.22
#   Retention Time: 14.21
#   Peak Height: 1060.78
#   All 1 peaks:
#     Peak 1 - RT: 14.21, Height: 1060.78, Area: 84.22
# n-9 Largest Peak Area: 604.45
#   Retention Time: 14.20
#   Peak Height: 4061.10
#   All 1 peaks:
#     Peak 1 - RT: 14.20, Height: 4061.10, Area: 604.45
#
# n-9/n-7 Ratio (largest peaks only): 7.1769
# ✅ Saved summary results for DegummedCanola_O3on_150gN3_02082023 → /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/df_DegummedCanola_O3on_150gN3_02082023_summary.csv
#    Columns: Sample_ID, Lipid, n-7_Area, n-9_Area, n-9/n-7_Ratio, n-7_Intensity, n-9_Intensity, n-9/n-7_Intensity_Ratio
#
# 🔍 Processing sample: RBDCanola_O3on_150gN3_02082023
#
# Peak Analysis for \[TG\(52:2\)\]_FA18:1 in RBDCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 269.68
#   Retention Time: 18.06
#   Peak Height: 2688.52
#   All 1 peaks:
#     Peak 1 - RT: 18.06, Height: 2688.52, Area: 269.68
# n-9 Largest Peak Area: 1307.63
#   Retention Time: 18.07
#   Peak Height: 12641.96
#   All 1 peaks:
#     Peak 1 - RT: 18.07, Height: 12641.96, Area: 1307.63
#
# n-9/n-7 Ratio (largest peaks only): 4.8488
#
# Peak Analysis for \[TG\(52:3\)\]_FA18:1 in RBDCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 141.92
#   Retention Time: 16.07
#   Peak Height: 1009.38
#   All 2 peaks:
#     Peak 1 - RT: 15.40, Height: 516.26, Area: 29.52
#     Peak 2 - RT: 16.07, Height: 1009.38, Area: 141.92
# n-9 Largest Peak Area: 366.93
#   Retention Time: 16.16
#   Peak Height: 3096.64
#   All 1 peaks:
#     Peak 1 - RT: 16.16, Height: 3096.64, Area: 366.93
#
# n-9/n-7 Ratio (largest peaks only): 2.5854
#
# Peak Analysis for \[TG\(52:4\)\]_FA18:1 in RBDCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 121.75
#   Retention Time: 14.31
#   Peak Height: 492.08
#   All 4 peaks:
#     Peak 1 - RT: 13.64, Height: 274.68, Area: 19.27
#     Peak 2 - RT: 14.23, Height: 473.46, Area: 20.74
#     Peak 3 - RT: 14.31, Height: 492.08, Area: 121.75
#     Peak 4 - RT: 15.11, Height: 319.44, Area: 40.90
# n-9 Largest Peak Area: 207.63
#   Retention Time: 14.35
#   Peak Height: 1317.20
#   All 1 peaks:
#     Peak 1 - RT: 14.35, Height: 1317.20, Area: 207.63
#
# n-9/n-7 Ratio (largest peaks only): 1.7053
#
# Peak Analysis for \[TG\(54:2\)\]_FA18:1 in RBDCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 216.32
#   Retention Time: 19.98
#   Peak Height: 1725.32
#   All 1 peaks:
#     Peak 1 - RT: 19.98, Height: 1725.32, Area: 216.32
# n-9 Largest Peak Area: 774.09
#   Retention Time: 20.04
#   Peak Height: 7721.20
#   All 1 peaks:
#     Peak 1 - RT: 20.04, Height: 7721.20, Area: 774.09
#
# n-9/n-7 Ratio (largest peaks only): 3.5784
#
# Peak Analysis for \[TG\(54:3\)\]_FA18:1 in RBDCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 1201.17
#   Retention Time: 18.01
#   Peak Height: 11771.02
#   All 1 peaks:
#     Peak 1 - RT: 18.01, Height: 11771.02, Area: 1201.17
# n-9 Largest Peak Area: 6674.50
#   Retention Time: 18.01
#   Peak Height: 63685.95
#   All 1 peaks:
#     Peak 1 - RT: 18.01, Height: 63685.95, Area: 6674.50
#
# n-9/n-7 Ratio (largest peaks only): 5.5567
#
# Peak Analysis for \[TG\(54:4\)\]_FA18:1 in RBDCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 401.52
#   Retention Time: 16.10
#   Peak Height: 3560.10
#   All 1 peaks:
#     Peak 1 - RT: 16.10, Height: 3560.10, Area: 401.52
# n-9 Largest Peak Area: 1803.82
#   Retention Time: 16.12
#   Peak Height: 17709.40
#   All 1 peaks:
#     Peak 1 - RT: 16.12, Height: 17709.40, Area: 1803.82
#
# n-9/n-7 Ratio (largest peaks only): 4.4925
#
# Peak Analysis for \[TG\(54:5\)\]_FA18:1 in RBDCanola_O3on_150gN3_02082023:
# --------------------------------------------------
# n-7 Largest Peak Area: 134.54
#   Retention Time: 14.28
#   Peak Height: 891.48
#   All 3 peaks:
#     Peak 1 - RT: 14.28, Height: 891.48, Area: 134.54
#     Peak 2 - RT: 14.37, Height: 814.62, Area: 35.06
#     Peak 3 - RT: 14.60, Height: 446.62, Area: 31.12
# n-9 Largest Peak Area: 550.07
#   Retention Time: 14.33
#   Peak Height: 3415.20
#   All 1 peaks:
#     Peak 1 - RT: 14.33, Height: 3415.20, Area: 550.07
#
# n-9/n-7 Ratio (largest peaks only): 4.0885
# ✅ Saved summary results for RBDCanola_O3on_150gN3_02082023 → /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/df_RBDCanola_O3on_150gN3_02082023_summary.csv
#    Columns: Sample_ID, Lipid, n-7_Area, n-9_Area, n-9/n-7_Ratio, n-7_Intensity, n-9_Intensity, n-9/n-7_Intensity_Ratio
#
# 📦 Saved combined summary for all samples → /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/df_all_samples_summary.csv
#    Shape: 21 rows × 8 columns
#    Columns: Sample_ID, Lipid, n-7_Area, n-9_Area, n-9/n-7_Ratio, n-7_Intensity, n-9_Intensity, n-9/n-7_Intensity_Ratio
#                           Sample_ID              Lipid     n-7_Area  \
# 0  CrudeCanola_O3on_150gN3_02082023  [TG(52:2)]_FA18:1   385.164882
# 1  CrudeCanola_O3on_150gN3_02082023  [TG(52:3)]_FA18:1   181.897408
# 2  CrudeCanola_O3on_150gN3_02082023  [TG(52:4)]_FA18:1   113.472247
# 3  CrudeCanola_O3on_150gN3_02082023  [TG(54:2)]_FA18:1   217.319776
# 4  CrudeCanola_O3on_150gN3_02082023  [TG(54:3)]_FA18:1  1585.371000
#
#       n-9_Area  n-9/n-7_Ratio  n-7_Intensity  n-9_Intensity  \
# 0  1594.448408       4.139652    3814.960205   16153.121094
# 1   403.309804       2.217238    1083.400024    3419.820312
# 2   255.856166       2.254791     615.420044    1874.780151
# 3  1178.185661       5.421438    2716.400146   11693.081055
# 4  9933.026601       6.265427   17186.220703   99860.148438
#
#    n-9/n-7_Intensity_Ratio
# 0                 4.234152
# 1                 3.156563
# 2                 3.046342
# 3                 4.304624
# 4                 5.810477

# %% [markdown]
# # Plot CLAW vs Manual Comparisons

# %%
from pathlib import Path

# Convert Project_results to Path object
Project_results = Path("/scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results")


SAMPLES = [
    {'name': 'Crude', 'sample_file': 'df_CrudeCanola_O3on_150gN3_02082023_summary.csv', 
     'manual_file': 'df_manual_crude.csv'},
    {'name': 'Degummed', 'sample_file': 'df_DegummedCanola_O3on_150gN3_02082023_summary.csv', 
     'manual_file': 'df_manual_degummed.csv'},
    {'name': 'RBD', 'sample_file': 'df_RBDCanola_O3on_150gN3_02082023_summary.csv', 
     'manual_file': 'df_manual_RBD.csv'}
]

# Create plot directories
(Project_results / "ratio_area").mkdir(parents=True, exist_ok=True)
(Project_results / "ratio_intensity").mkdir(parents=True, exist_ok=True)

for sample in SAMPLES:
    sample_csv = Project_results / sample['sample_file']
    manual_csv = Project_results / sample['manual_file']
    
    if sample_csv.exists() and manual_csv.exists():
        # Area-based ratios
        plot_n9_n7_ratios(
            sample_csv_path=str(sample_csv),
            manual_csv_path=str(manual_csv),
            sample_label=f'{sample["name"]} CLAW Area',
            manual_label=f'{sample["name"]} Manual Area',
            file_path=str(Project_results / "ratio_area" / f"{sample['name']}_area_ratios")
        )
        
        # Intensity-based ratios
        plot_n9_n7_ratios_intensity(
            sample_csv_path=str(sample_csv),
            manual_csv_path=str(manual_csv),
            sample_label=f'{sample["name"]} CLAW Intensity',
            manual_label=f'{sample["name"]} Manual Area',
            file_path=str(Project_results / "ratio_intensity" / f"{sample['name']}_intensity_ratios")
        )

print(f"✓ Area plots saved to: {Project_results / 'ratio_area'}")
print(f"✓ Intensity plots saved to: {Project_results / 'ratio_intensity'}")
# Out:
# Saved PNG: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Crude_area_ratios.png
# Saved PDF: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Crude_area_ratios.pdf
# Saved sample CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Crude_area_ratios_sample_df_20251105.csv
# Saved manual CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Crude_area_ratios_manual_df_20251105.csv
# Saved PNG: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Crude_intensity_ratios.png
# Saved PDF: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Crude_intensity_ratios.pdf
# Saved sample intensity CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Crude_intensity_ratios_sample_intensity_df_20251105.csv
# Saved manual CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Crude_intensity_ratios_manual_df_20251105.csv
# Saved PNG: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Degummed_area_ratios.png
# Saved PDF: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Degummed_area_ratios.pdf
# Saved sample CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Degummed_area_ratios_sample_df_20251105.csv
# Saved manual CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/Degummed_area_ratios_manual_df_20251105.csv
# Saved PNG: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Degummed_intensity_ratios.png
# Saved PDF: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Degummed_intensity_ratios.pdf
# Saved sample intensity CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Degummed_intensity_ratios_sample_intensity_df_20251105.csv
# Saved manual CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/Degummed_intensity_ratios_manual_df_20251105.csv
# Saved PNG: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/RBD_area_ratios.png
# Saved PDF: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/RBD_area_ratios.pdf
# Saved sample CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/RBD_area_ratios_sample_df_20251105.csv
# Saved manual CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area/RBD_area_ratios_manual_df_20251105.csv
# Saved PNG: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/RBD_intensity_ratios.png
# Saved PDF: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/RBD_intensity_ratios.pdf
# Saved sample intensity CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/RBD_intensity_ratios_sample_intensity_df_20251105.csv
# Saved manual CSV: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity/RBD_intensity_ratios_manual_df_20251105.csv
# ✓ Area plots saved to: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_area
# ✓ Intensity plots saved to: /scratch/negishi/iyer95/iyer95/CLAW_OzESI_Paper/OzESI_MUFA_paper/lipid_platform/Projects/canola_tutorial/results/ratio_intensity
